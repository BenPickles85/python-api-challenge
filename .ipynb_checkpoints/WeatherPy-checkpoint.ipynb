# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Dependencies
import matplotlib.pyplot as plt
import requests
from scipy import stats
import numpy as np
import pandas as pd
from pprint import pprint
from citipy import citipy
from scipy.stats import linregress

from config import api_key

# %% [markdown]
# ## Generate Cities List

# %%
#Generate and store pairs of coordinates
longs = np.random.uniform(low=-180, high=180, size=1200)
lats = np.random.uniform(low=-50, high=70, size=1200)
coordinates = tuple(zip(lats, longs))

# %%
city_list = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in city_list:
            city_list.append(city)
print(city_list[0:10])
# Out:
# ['soyo', 'atuona', 'port elizabeth', 'kapaa', 'maierus', 'gogrial', 'san andres', 'puerto ayora', 'sofiysk', 'taolanaro']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city = city_list[0]
units = 'imperial'
query_url = f'http://api.openweathermap.org/data/2.5/weather?&appid={api_key}&units={units}&q='
response = requests.get(query_url + city).json()
response
# Out:
# {'coord': {'lon': 12.3689, 'lat': -6.1349},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 74.37,
#   'feels_like': 75.65,
#   'temp_min': 74.37,
#   'temp_max': 74.37,
#   'pressure': 1013,
#   'humidity': 88,
#   'sea_level': 1013,
#   'grnd_level': 1012},
#  'visibility': 10000,
#  'wind': {'speed': 7.47, 'deg': 215, 'gust': 13.24},
#  'clouds': {'all': 42},
#  'dt': 1631569765,
#  'sys': {'country': 'AO', 'sunrise': 1631509490, 'sunset': 1631552899},
#  'timezone': 3600,
#  'id': 2236967,
#  'name': 'Soyo',
#  'cod': 200}

# %%
#Generate list of cities using randomised coordinates

#Create lists
lat = []
long = []
long = []
temp_f = []
humidity = []
cloudiness = []
wind_speeds = []
cities = []
country = []
city_number = 0

#Define url and units
units = 'imperial'
query_url = f'http://api.openweathermap.org/data/2.5/weather?&appid={api_key}&units={units}&q='


for city in city_list:
    try:
        response = requests.get(query_url + city).json()

    #Append results to lists
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        temp_f.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speeds.append(response['wind']['speed'])
        cities.append(city)
        country.append(response['sys']['country'])
        city_number += 1
        
    #Print outcome if city found
        print(f'City Number: {city_number}, City Name: {city}')
    
    #Print outcome if city not found
    except KeyError:
        print(f'{city} - city not found')
# Out:
# City Number: 1, City Name: soyo
# City Number: 2, City Name: atuona
# City Number: 3, City Name: port elizabeth
# City Number: 4, City Name: kapaa
# City Number: 5, City Name: maierus
# City Number: 6, City Name: gogrial
# City Number: 7, City Name: san andres
# City Number: 8, City Name: puerto ayora
# sofiysk - city not found
# taolanaro - city not found
# City Number: 9, City Name: shitanjing
# City Number: 10, City Name: noumea
# City Number: 11, City Name: acapulco
# City Number: 12, City Name: khrenovoye
# City Number: 13, City Name: hithadhoo
# City Number: 14, City Name: luangwa
# City Number: 15, City Name: jamestown
# City Number: 16, City Name: kitimat
# City Number: 17, City Name: east london
# City Number: 18, City Name: yabelo
# City Number: 19, City Name: hermanus
# City Number: 20, City Name: novoagansk
# City Number: 21, City Name: souillac
# City Number: 22, City Name: paamiut
# City Number: 23, City Name: merauke
# City Number: 24, City Name: plattsburgh
# City Number: 25, City Name: stornoway
# City Number: 26, City Name: airai
# City Number: 27, City Name: nagato
# City Number: 28, City Name: zholymbet
# City Number: 29, City Name: san patricio
# City Number: 30, City Name: pisco
# umm ruwabah - city not found
# City Number: 31, City Name: iqaluit
# City Number: 32, City Name: saint-augustin
# City Number: 33, City Name: saint-philippe
# City Number: 34, City Name: ambo
# City Number: 35, City Name: kysyl-syr
# samalaeulu - city not found
# City Number: 36, City Name: linxia
# City Number: 37, City Name: nova olimpia
# City Number: 38, City Name: skogn
# City Number: 39, City Name: te anau
# City Number: 40, City Name: esperance
# City Number: 41, City Name: butaritari
# City Number: 42, City Name: mestia
# City Number: 43, City Name: saint-francois
# City Number: 44, City Name: darhan
# City Number: 45, City Name: lebu
# City Number: 46, City Name: provideniya
# City Number: 47, City Name: issoire
# City Number: 48, City Name: cape town
# City Number: 49, City Name: avera
# City Number: 50, City Name: marzuq
# City Number: 51, City Name: chuy
# City Number: 52, City Name: rikitea
# City Number: 53, City Name: acarau
# City Number: 54, City Name: ancud
# City Number: 55, City Name: lompoc
# City Number: 56, City Name: tornio
# City Number: 57, City Name: hilo
# City Number: 58, City Name: avarua
# City Number: 59, City Name: barrow
# City Number: 60, City Name: waipawa
# City Number: 61, City Name: kodiak
# City Number: 62, City Name: puerto leguizamo
# City Number: 63, City Name: fairbanks
# City Number: 64, City Name: kavieng
# City Number: 65, City Name: mandalgovi
# City Number: 66, City Name: luderitz
# City Number: 67, City Name: zwedru
# City Number: 68, City Name: lakefield
# City Number: 69, City Name: beyneu
# City Number: 70, City Name: hasaki
# City Number: 71, City Name: namibe
# City Number: 72, City Name: puri
# City Number: 73, City Name: georgetown
# City Number: 74, City Name: alta floresta
# City Number: 75, City Name: arraial do cabo
# City Number: 76, City Name: kulhudhuffushi
# azimur - city not found
# City Number: 77, City Name: hofn
# City Number: 78, City Name: zambezi
# City Number: 79, City Name: ribeira grande
# City Number: 80, City Name: quzhou
# City Number: 81, City Name: mabaruma
# City Number: 82, City Name: bambous virieux
# City Number: 83, City Name: ponta do sol
# City Number: 84, City Name: kuito
# City Number: 85, City Name: haines junction
# City Number: 86, City Name: panguna
# City Number: 87, City Name: kaeo
# City Number: 88, City Name: inyonga
# City Number: 89, City Name: yulara
# City Number: 90, City Name: kavaratti
# City Number: 91, City Name: albany
# City Number: 92, City Name: karasjok
# City Number: 93, City Name: komatipoort
# City Number: 94, City Name: mahebourg
# City Number: 95, City Name: bubaque
# City Number: 96, City Name: lombardia
# City Number: 97, City Name: san jose
# City Number: 98, City Name: constitucion
# City Number: 99, City Name: fortuna
# City Number: 100, City Name: artyom
# City Number: 101, City Name: olafsvik
# City Number: 102, City Name: busselton
# City Number: 103, City Name: george
# City Number: 104, City Name: martapura
# City Number: 105, City Name: paita
# City Number: 106, City Name: vaini
# City Number: 107, City Name: carnarvon
# City Number: 108, City Name: touros
# City Number: 109, City Name: castro
# City Number: 110, City Name: saldanha
# City Number: 111, City Name: arman
# City Number: 112, City Name: cockburn town
# City Number: 113, City Name: brae
# City Number: 114, City Name: nikolskoye
# City Number: 115, City Name: sabang
# City Number: 116, City Name: srandakan
# City Number: 117, City Name: la ronge
# City Number: 118, City Name: alyangula
# City Number: 119, City Name: kodinsk
# City Number: 120, City Name: richards bay
# City Number: 121, City Name: codrington
# City Number: 122, City Name: zyryanka
# palabuhanratu - city not found
# City Number: 123, City Name: prince george
# afmadu - city not found
# City Number: 124, City Name: atbasar
# City Number: 125, City Name: mataura
# City Number: 126, City Name: cidreira
# City Number: 127, City Name: alyth
# City Number: 128, City Name: saint-pierre
# attawapiskat - city not found
# City Number: 129, City Name: sao joao da barra
# City Number: 130, City Name: jinchang
# City Number: 131, City Name: atar
# City Number: 132, City Name: petropavlovsk-kamchatskiy
# City Number: 133, City Name: kassala
# City Number: 134, City Name: nabire
# City Number: 135, City Name: tyshkivka
# City Number: 136, City Name: frankfort
# City Number: 137, City Name: johnston
# City Number: 138, City Name: shihezi
# City Number: 139, City Name: honiara
# City Number: 140, City Name: masunga
# City Number: 141, City Name: caucaia
# City Number: 142, City Name: garowe
# City Number: 143, City Name: stuttgart
# City Number: 144, City Name: bethel
# doctor pedro p. pena - city not found
# City Number: 145, City Name: ardesen
# City Number: 146, City Name: groningen
# City Number: 147, City Name: naze
# City Number: 148, City Name: kahului
# City Number: 149, City Name: fukue
# City Number: 150, City Name: rovaniemi
# City Number: 151, City Name: kapuskasing
# saleaula - city not found
# City Number: 152, City Name: siilinjarvi
# liminangcong - city not found
# City Number: 153, City Name: rawson
# samusu - city not found
# haibowan - city not found
# City Number: 154, City Name: maneromango
# City Number: 155, City Name: mokrous
# City Number: 156, City Name: kupang
# City Number: 157, City Name: yaan
# City Number: 158, City Name: najran
# City Number: 159, City Name: irtyshskiy
# City Number: 160, City Name: havre-saint-pierre
# City Number: 161, City Name: dunedin
# City Number: 162, City Name: cavalcante
# City Number: 163, City Name: tarakan
# City Number: 164, City Name: nha trang
# City Number: 165, City Name: minatitlan
# City Number: 166, City Name: ankazobe
# City Number: 167, City Name: hobyo
# City Number: 168, City Name: bam
# saint combs - city not found
# City Number: 169, City Name: madera
# City Number: 170, City Name: yelan
# City Number: 171, City Name: huilong
# grand river south east - city not found
# City Number: 172, City Name: saint george
# City Number: 173, City Name: kholtoson
# City Number: 174, City Name: cabo san lucas
# City Number: 175, City Name: belyy yar
# borama - city not found
# City Number: 176, City Name: bengkulu
# City Number: 177, City Name: coihaique
# City Number: 178, City Name: tasiilaq
# City Number: 179, City Name: chengde
# City Number: 180, City Name: manzhouli
# City Number: 181, City Name: miri
# City Number: 182, City Name: victoria
# City Number: 183, City Name: luang prabang
# City Number: 184, City Name: pochutla
# City Number: 185, City Name: falmouth
# City Number: 186, City Name: severo-kurilsk
# City Number: 187, City Name: osakarovka
# City Number: 188, City Name: sar-e pul
# City Number: 189, City Name: ugoofaaru
# City Number: 190, City Name: westport
# City Number: 191, City Name: alvorada
# City Number: 192, City Name: pierre
# City Number: 193, City Name: erenhot
# City Number: 194, City Name: port hedland
# City Number: 195, City Name: mporokoso
# City Number: 196, City Name: barcelona
# City Number: 197, City Name: baker city
# City Number: 198, City Name: naron
# City Number: 199, City Name: tautira
# inderborskiy - city not found
# City Number: 200, City Name: wanaka
# City Number: 201, City Name: olga
# City Number: 202, City Name: pangnirtung
# City Number: 203, City Name: dwarka
# City Number: 204, City Name: klyuchevskiy
# City Number: 205, City Name: thompson
# City Number: 206, City Name: callaway
# City Number: 207, City Name: saint-benoit
# City Number: 208, City Name: faanui
# toliary - city not found
# City Number: 209, City Name: ahvaz
# City Number: 210, City Name: kuytun
# City Number: 211, City Name: bereda
# City Number: 212, City Name: vila franca do campo
# City Number: 213, City Name: suntar
# City Number: 214, City Name: fort nelson
# City Number: 215, City Name: imeni poliny osipenko
# City Number: 216, City Name: abeche
# City Number: 217, City Name: umm lajj
# City Number: 218, City Name: laguna
# City Number: 219, City Name: guerrero negro
# City Number: 220, City Name: asau
# sinjah - city not found
# City Number: 221, City Name: mamonit
# City Number: 222, City Name: thayetmyo
# City Number: 223, City Name: tselinnoye
# City Number: 224, City Name: filingue
# City Number: 225, City Name: rodrigues alves
# City Number: 226, City Name: kieta
# City Number: 227, City Name: salalah
# City Number: 228, City Name: chardara
# City Number: 229, City Name: karwar
# City Number: 230, City Name: pyaozerskiy
# City Number: 231, City Name: parana
# City Number: 232, City Name: alakurtti
# City Number: 233, City Name: caravelas
# City Number: 234, City Name: vuktyl
# City Number: 235, City Name: olinda
# talawdi - city not found
# City Number: 236, City Name: mgandu
# City Number: 237, City Name: tura
# City Number: 238, City Name: muros
# City Number: 239, City Name: guymon
# City Number: 240, City Name: puerto gaitan
# City Number: 241, City Name: marawi
# City Number: 242, City Name: christchurch
# City Number: 243, City Name: tres arroyos
# City Number: 244, City Name: yar-sale
# City Number: 245, City Name: walvis bay
# City Number: 246, City Name: mindelo
# City Number: 247, City Name: zhigansk
# City Number: 248, City Name: kohat
# City Number: 249, City Name: chernelytsya
# City Number: 250, City Name: tecoanapa
# City Number: 251, City Name: anloga
# City Number: 252, City Name: kisangani
# City Number: 253, City Name: isa khel
# City Number: 254, City Name: inhambane
# City Number: 255, City Name: aba
# City Number: 256, City Name: puerto del rosario
# City Number: 257, City Name: los llanos de aridane
# City Number: 258, City Name: gejiu
# City Number: 259, City Name: maragogi
# City Number: 260, City Name: qaqortoq
# City Number: 261, City Name: viransehir
# sedelnikovo - city not found
# City Number: 262, City Name: amahai
# City Number: 263, City Name: aswan
# felidhoo - city not found
# City Number: 264, City Name: bathsheba
# City Number: 265, City Name: adrar
# City Number: 266, City Name: husavik
# City Number: 267, City Name: hargeysa
# City Number: 268, City Name: whitehorse
# City Number: 269, City Name: taltal
# City Number: 270, City Name: queanbeyan
# City Number: 271, City Name: annau
# City Number: 272, City Name: padang
# City Number: 273, City Name: ulaangom
# City Number: 274, City Name: awjilah
# sorvag - city not found
# City Number: 275, City Name: maningrida
# City Number: 276, City Name: san cristobal
# City Number: 277, City Name: nueva loja
# City Number: 278, City Name: qui nhon
# City Number: 279, City Name: pacasmayo
# City Number: 280, City Name: rize
# City Number: 281, City Name: nelson bay
# City Number: 282, City Name: umm kaddadah
# City Number: 283, City Name: fairview
# City Number: 284, City Name: ko samui
# City Number: 285, City Name: sitka
# City Number: 286, City Name: deputatskiy
# City Number: 287, City Name: sambava
# City Number: 288, City Name: poum
# City Number: 289, City Name: billere
# City Number: 290, City Name: sibolga
# bacuit - city not found
# City Number: 291, City Name: samarai
# City Number: 292, City Name: nalut
# City Number: 293, City Name: beringovskiy
# City Number: 294, City Name: isla vista
# City Number: 295, City Name: cervo
# City Number: 296, City Name: matara
# City Number: 297, City Name: manicore
# City Number: 298, City Name: ouallam
# City Number: 299, City Name: valparaiso
# City Number: 300, City Name: russell
# City Number: 301, City Name: jutai
# City Number: 302, City Name: vista hermosa
# City Number: 303, City Name: doka
# City Number: 304, City Name: vila
# City Number: 305, City Name: farah
# City Number: 306, City Name: maniitsoq
# City Number: 307, City Name: isangel
# City Number: 308, City Name: karatuzskoye
# City Number: 309, City Name: sao felix do xingu
# City Number: 310, City Name: gallikos
# City Number: 311, City Name: presque isle
# City Number: 312, City Name: gangtok
# City Number: 313, City Name: nhulunbuy
# City Number: 314, City Name: chirongui
# City Number: 315, City Name: preeceville
# City Number: 316, City Name: nanortalik
# City Number: 317, City Name: colares
# City Number: 318, City Name: grand gaube
# City Number: 319, City Name: tashtyp
# City Number: 320, City Name: cairo
# mocambique - city not found
# City Number: 321, City Name: sri aman
# City Number: 322, City Name: vanimo
# City Number: 323, City Name: faya
# City Number: 324, City Name: salinas
# City Number: 325, City Name: mitchell
# City Number: 326, City Name: lasa
# City Number: 327, City Name: bintulu
# City Number: 328, City Name: dalbandin
# City Number: 329, City Name: karasburg
# vaitupu - city not found
# City Number: 330, City Name: buchanan
# naftah - city not found
# City Number: 331, City Name: horki
# City Number: 332, City Name: port hardy
# City Number: 333, City Name: pokrovsk
# City Number: 334, City Name: bilibino
# City Number: 335, City Name: comodoro rivadavia
# City Number: 336, City Name: ahipara
# City Number: 337, City Name: bichena
# City Number: 338, City Name: yichun
# City Number: 339, City Name: hovd
# City Number: 340, City Name: manono
# City Number: 341, City Name: pyapon
# City Number: 342, City Name: ambilobe
# City Number: 343, City Name: katsuura
# City Number: 344, City Name: morrope
# City Number: 345, City Name: lambari
# City Number: 346, City Name: san quintin
# City Number: 347, City Name: minab
# City Number: 348, City Name: skelleftea
# City Number: 349, City Name: klaksvik
# City Number: 350, City Name: college
# City Number: 351, City Name: surskoye
# City Number: 352, City Name: isla mujeres
# City Number: 353, City Name: auki
# City Number: 354, City Name: launceston
# City Number: 355, City Name: beaufort
# City Number: 356, City Name: buncrana
# City Number: 357, City Name: torbay
# City Number: 358, City Name: sofia
# City Number: 359, City Name: galbshtadt
# City Number: 360, City Name: chapais
# City Number: 361, City Name: tual
# City Number: 362, City Name: surovikino
# kamenskoye - city not found
# City Number: 363, City Name: arandis
# City Number: 364, City Name: voyvozh
# stamsund - city not found
# City Number: 365, City Name: valleyview
# City Number: 366, City Name: kensington
# City Number: 367, City Name: jiwani
# City Number: 368, City Name: matelandia
# City Number: 369, City Name: kozhevnikovo
# City Number: 370, City Name: iralaya
# City Number: 371, City Name: hambantota
# City Number: 372, City Name: labuhan
# City Number: 373, City Name: puro
# City Number: 374, City Name: saint-georges
# City Number: 375, City Name: new norfolk
# City Number: 376, City Name: wenatchee
# temaraia - city not found
# City Number: 377, City Name: kununurra
# City Number: 378, City Name: zaysan
# City Number: 379, City Name: buala
# City Number: 380, City Name: catuday
# City Number: 381, City Name: sao filipe
# City Number: 382, City Name: pitimbu
# City Number: 383, City Name: mar del plata
# City Number: 384, City Name: moron
# City Number: 385, City Name: taikang
# City Number: 386, City Name: lavrentiya
# palkaka - city not found
# City Number: 387, City Name: axel
# tsihombe - city not found
# City Number: 388, City Name: khuzhir
# City Number: 389, City Name: maindargi
# City Number: 390, City Name: darnah
# City Number: 391, City Name: aksu
# City Number: 392, City Name: buenos aires
# City Number: 393, City Name: arroyo
# City Number: 394, City Name: ucluelet
# City Number: 395, City Name: sakakah
# City Number: 396, City Name: bom jesus
# City Number: 397, City Name: robertsport
# City Number: 398, City Name: quelimane
# City Number: 399, City Name: guanica
# City Number: 400, City Name: rio gallegos
# City Number: 401, City Name: haicheng
# City Number: 402, City Name: leshukonskoye
# City Number: 403, City Name: heihe
# City Number: 404, City Name: forquilhinha
# City Number: 405, City Name: kitwe
# City Number: 406, City Name: kendari
# City Number: 407, City Name: kutum
# City Number: 408, City Name: tabou
# City Number: 409, City Name: aksay
# City Number: 410, City Name: owasso
# City Number: 411, City Name: bokovskaya
# City Number: 412, City Name: tuatapere
# paradwip - city not found
# aflu - city not found
# City Number: 413, City Name: hirara
# City Number: 414, City Name: hazaribag
# City Number: 415, City Name: la palma
# City Number: 416, City Name: arlit
# City Number: 417, City Name: matagami
# artyk - city not found
# City Number: 418, City Name: geraldton
# City Number: 419, City Name: ciudad valles
# bolungarvik - city not found
# City Number: 420, City Name: les escoumins
# City Number: 421, City Name: chernyshevskiy
# City Number: 422, City Name: iranshahr
# City Number: 423, City Name: arcata
# tabukiniberu - city not found
# City Number: 424, City Name: benemerito de las americas
# City Number: 425, City Name: atocha
# mutsamudu - city not found
# City Number: 426, City Name: viseu
# City Number: 427, City Name: goderich
# City Number: 428, City Name: bonavista
# City Number: 429, City Name: cabedelo
# cazaje - city not found
# City Number: 430, City Name: manggar
# City Number: 431, City Name: llanes
# City Number: 432, City Name: cahors
# City Number: 433, City Name: palmer
# City Number: 434, City Name: high level
# City Number: 435, City Name: vostok
# City Number: 436, City Name: aklavik
# City Number: 437, City Name: novyye burasy
# City Number: 438, City Name: vao
# City Number: 439, City Name: benguela
# City Number: 440, City Name: kosonsoy
# City Number: 441, City Name: carutapera
# City Number: 442, City Name: shanting
# City Number: 443, City Name: chake chake
# City Number: 444, City Name: aras
# City Number: 445, City Name: grindavik
# City Number: 446, City Name: svetlyy
# City Number: 447, City Name: mamou
# City Number: 448, City Name: alekseyevsk
# City Number: 449, City Name: nargana
# City Number: 450, City Name: ozernovskiy
# City Number: 451, City Name: eureka
# City Number: 452, City Name: henties bay
# City Number: 453, City Name: tezu
# City Number: 454, City Name: plettenberg bay
# City Number: 455, City Name: dingle
# City Number: 456, City Name: boyabat
# City Number: 457, City Name: abu samrah
# City Number: 458, City Name: yellowknife
# City Number: 459, City Name: kikwit
# City Number: 460, City Name: sanbu
# City Number: 461, City Name: sakaiminato
# City Number: 462, City Name: ulladulla
# City Number: 463, City Name: gra liyia
# City Number: 464, City Name: sisimiut
# City Number: 465, City Name: morros
# City Number: 466, City Name: tazovskiy
# City Number: 467, City Name: gamba
# City Number: 468, City Name: clyde river
# City Number: 469, City Name: chipata
# City Number: 470, City Name: wamba
# City Number: 471, City Name: mount gambier
# City Number: 472, City Name: copiapo
# City Number: 473, City Name: makurdi
# City Number: 474, City Name: prieska
# City Number: 475, City Name: ambovombe
# City Number: 476, City Name: estevan
# City Number: 477, City Name: north platte
# wulanhaote - city not found
# City Number: 478, City Name: rio cuarto
# City Number: 479, City Name: niamey
# City Number: 480, City Name: vallenar
# City Number: 481, City Name: port lincoln
# City Number: 482, City Name: fez
# City Number: 483, City Name: tocopilla
# City Number: 484, City Name: okhotsk
# City Number: 485, City Name: ola
# City Number: 486, City Name: loukhi
# City Number: 487, City Name: yangambi
# City Number: 488, City Name: alice springs
# City Number: 489, City Name: gari
# City Number: 490, City Name: ciudad bolivar
# City Number: 491, City Name: meulaboh
# City Number: 492, City Name: tokmak
# City Number: 493, City Name: litovko
# City Number: 494, City Name: bedesa
# City Number: 495, City Name: nosy varika
# ngukurr - city not found
# City Number: 496, City Name: forecariah
# City Number: 497, City Name: belaya gora
# City Number: 498, City Name: mechetinskaya
# City Number: 499, City Name: muisne
# City Number: 500, City Name: baiyin
# hihifo - city not found
# City Number: 501, City Name: nioro
# City Number: 502, City Name: dobanovci
# City Number: 503, City Name: ukiah
# City Number: 504, City Name: simao
# City Number: 505, City Name: huasahuasi
# City Number: 506, City Name: jumla
# City Number: 507, City Name: pandan niog
# City Number: 508, City Name: sinazongwe
# City Number: 509, City Name: tera
# City Number: 510, City Name: koungou
# City Number: 511, City Name: nanakuli
# City Number: 512, City Name: muscat
# City Number: 513, City Name: morondava
# City Number: 514, City Name: kruisfontein
# City Number: 515, City Name: cherskiy
# City Number: 516, City Name: pacifica
# City Number: 517, City Name: point pedro
# City Number: 518, City Name: micheweni
# City Number: 519, City Name: chumikan
# City Number: 520, City Name: gat
# City Number: 521, City Name: freeport
# City Number: 522, City Name: portland
# City Number: 523, City Name: nantucket
# City Number: 524, City Name: dubbo
# City Number: 525, City Name: ngorongoro
# City Number: 526, City Name: perth
# City Number: 527, City Name: bykovo
# City Number: 528, City Name: khandyga
# City Number: 529, City Name: vysokogornyy
# City Number: 530, City Name: urengoy
# City Number: 531, City Name: kenai
# City Number: 532, City Name: balkanabat
# City Number: 533, City Name: west bay
# tasbuget - city not found
# City Number: 534, City Name: gilbues
# City Number: 535, City Name: jaunpur
# City Number: 536, City Name: casablanca
# City Number: 537, City Name: smirnykh
# City Number: 538, City Name: farafangana
# City Number: 539, City Name: hualmay
# City Number: 540, City Name: stromness
# City Number: 541, City Name: waddan
# City Number: 542, City Name: takoradi
# City Number: 543, City Name: wau
# City Number: 544, City Name: cayenne
# City Number: 545, City Name: hamilton
# City Number: 546, City Name: jiexiu
# City Number: 547, City Name: bredasdorp
# City Number: 548, City Name: manakara
# City Number: 549, City Name: neyvo-shaytanskiy
# City Number: 550, City Name: vestmannaeyjar
# City Number: 551, City Name: ghoti
# City Number: 552, City Name: mizan teferi
# City Number: 553, City Name: urumqi
# City Number: 554, City Name: iwaki
# City Number: 555, City Name: eurajoki
# City Number: 556, City Name: moose factory
# City Number: 557, City Name: el retorno
# City Number: 558, City Name: grand-santi
# fort saint john - city not found
# City Number: 559, City Name: zaltan
# City Number: 560, City Name: la paz
# City Number: 561, City Name: shalya
# City Number: 562, City Name: kingaroy
# jiddah - city not found
# City Number: 563, City Name: hobart
# City Number: 564, City Name: blind river
# City Number: 565, City Name: taywarah
# City Number: 566, City Name: namatanai
# City Number: 567, City Name: dobryatino
# City Number: 568, City Name: ostersund
# City Number: 569, City Name: north bend
# City Number: 570, City Name: kamwenge
# marcona - city not found
# City Number: 571, City Name: basco
# City Number: 572, City Name: abu dhabi
# City Number: 573, City Name: tsiroanomandidy
# City Number: 574, City Name: dunhua
# City Number: 575, City Name: gwadar
# City Number: 576, City Name: ilo
# City Number: 577, City Name: monster
# City Number: 578, City Name: shelburne
# City Number: 579, City Name: erzin
# City Number: 580, City Name: coquimbo
# taburi - city not found
# warqla - city not found
# City Number: 581, City Name: hilton head island
# City Number: 582, City Name: ushirombo
# City Number: 583, City Name: emerald
# City Number: 584, City Name: nagai
# City Number: 585, City Name: onega
# City Number: 586, City Name: ylivieska
# City Number: 587, City Name: puerto varas
# City Number: 588, City Name: rio grande
# City Number: 589, City Name: coria
# City Number: 590, City Name: yerbogachen
# City Number: 591, City Name: ust-kuyga
# City Number: 592, City Name: pimentel
# City Number: 593, City Name: bafq
# City Number: 594, City Name: lorengau
# City Number: 595, City Name: champerico
# City Number: 596, City Name: moerai
# City Number: 597, City Name: liwonde
# mullaitivu - city not found
# City Number: 598, City Name: krasnoselkup
# City Number: 599, City Name: ishigaki
# City Number: 600, City Name: oussouye
# umzimvubu - city not found
# City Number: 601, City Name: nizhnevartovsk
# City Number: 602, City Name: senador jose porfirio
# City Number: 603, City Name: ponta delgada
# City Number: 604, City Name: broome
# City Number: 605, City Name: wahiawa
# City Number: 606, City Name: scarborough
# City Number: 607, City Name: manzanillo
# City Number: 608, City Name: wanning
# City Number: 609, City Name: beloha

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create dataframe using list of cities
weather_df = pd.DataFrame({"City":cities, "Country": country, "Latitude":lat, "Longitude": long, "Cloudiness":cloudiness, 
                           "Humidity":humidity, "Temperature":temp_f, "Wind Speed":wind_speeds})
weather_df['City'] = weather_df['City'].str.title()
weather_df.head()
# Out:
#              City Country  Latitude  Longitude  Cloudiness  Humidity  \
# 0            Soyo      AO   -6.1349    12.3689          42        88
# 1          Atuona      PF   -9.8000  -139.0333          36        68
# 2  Port Elizabeth      ZA  -33.9180    25.5701          90       100
# 3           Kapaa      US   22.0752  -159.3190          40        66
# 4         Maierus      RO   45.9000    25.5333          10        74
#
#    Temperature  Wind Speed
# 0        74.37        7.47
# 1        77.85       20.92
# 2        57.49       16.11
# 3        81.55        3.00
# 4        53.46        1.28

# %%
#Save DataFrame as CSV
weather_df.to_csv('Output_CSV/weather_df.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Determine if any cities have humidity >100%
weather_df.describe()
# Out:
#          Latitude   Longitude  Cloudiness    Humidity  Temperature  Wind Speed
# count  609.000000  609.000000  609.000000  609.000000   609.000000  609.000000
# mean    19.152298   19.434792   57.008210   71.425287    65.980443    7.784384
# std     31.979912   87.096663   39.611413   21.013657    14.631447    6.051117
# min    -51.622600 -175.200000    0.000000    9.000000    32.050000    0.000000
# 25%     -7.300000  -58.377200   13.000000   60.000000    53.890000    3.440000
# 50%     22.075200   27.416700   72.000000   76.000000    68.450000    6.260000
# 75%     46.485600   91.641900   96.000000   87.000000    77.310000   10.400000
# max     71.290600  179.316700  100.000000  100.000000   100.270000   40.130000

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Temperature"], edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Temperature", size="16")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("Plots/lat_vs_temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Humidity"], cmap="BlYlRd", edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (%)", size="16")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("Plots/lat_vs_humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Cloudiness"], cmap="BlYlRd", edgecolors="black",facecolors="mediumorchid")
plt.title("City Latitude vs. Cloudiness", size="16")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("Plots/lat_vs_clouds.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Wind Speed"], cmap="BlYlRd", edgecolors="black",facecolors="gold")
plt.title("City Latitude vs. Wind Speed (mph)", size="16")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("Plots/lat_vs_wind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Split into northern and souther hemisphere DataFrames
southern_df = weather_df.loc[(weather_df['Latitude']<0)]
northern_df = weather_df.loc[(weather_df['Latitude']>=0)]

# %%
#Set base function for all linear regression plots
def linear_regression(x_values, y_values, y_title, hemisphere):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    fig1, ax1 = plt.subplots(figsize=(6, 4))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    
    #Set and format title and axis label
    plt.title(f'{y_title} vs Latitude\n{hemisphere} Hemisphere',fontsize =14)
    plt.xlabel("Latitude",fontsize =12)
    plt.ylabel(y_title,fontsize =12)
    
    #Print r value
    print(f"The r-squared for the {hemisphere} Hemisphere is: {rvalue**2}")
    plt.savefig(f"Plots/{hemisphere}_Hemisphere_{y_title}_vs_Latitude.png")
    
    #Generate plot
    plt.show()

# %%
#linear regression plots, Northern vs Southern Hempishphere for latitude vs temperature
x_values = northern_df['Latitude']
y_values = northern_df['Temperature']
linear_regression(x_values, y_values, 'Temperature', 'Northern')

x_values = southern_df['Latitude']
y_values = southern_df['Temperature']
linear_regression(x_values, y_values, 'Temperature', 'Southern')
# Out:
# The r-squared for the Northern Hemisphere is: 0.5938750677224078
# The r-squared for the Southern Hemisphere is: 0.6175525243228162

# %%
#linear regression plots, Northern vs Southern Hempishphere for latitude vs humidity
x_values = northern_df['Latitude']
y_values = northern_df['Humidity']
linear_regression(x_values, y_values, 'Humidity', 'Northern')

x_values = southern_df['Latitude']
y_values = southern_df['Humidity']
linear_regression(x_values, y_values, 'Humidity', 'Southern')
# Out:
# The r-squared for the Northern Hemisphere is: 0.0024860325278283093
# The r-squared for the Southern Hemisphere is: 0.0014768930927121513

# %%
#linear regression plots, Northern vs Southern Hempishphere for latitude vs cloudiness
x_values = northern_df['Latitude']
y_values = northern_df['Cloudiness']
linear_regression(x_values, y_values, 'Cloudiness', 'Northern')

x_values = southern_df['Latitude']
y_values = southern_df['Cloudiness']
linear_regression(x_values, y_values, 'Cloudiness', 'Southern')
# Out:
# The r-squared for the Northern Hemisphere is: 7.141991698481399e-07
# The r-squared for the Southern Hemisphere is: 0.0017375885659330328

# %%
#linear regression plots, Northern vs Southern Hempishphere for latitude vs wind speed
x_values = northern_df['Latitude']
y_values = northern_df['Wind Speed']
linear_regression(x_values, y_values, 'Wind Speed', 'Northern')

x_values = southern_df['Latitude']
y_values = southern_df['Wind Speed']
linear_regression(x_values, y_values, 'Wind Speed', 'Southern')
# Out:
# The r-squared for the Northern Hemisphere is: 0.016047042389582964
# The r-squared for the Southern Hemisphere is: 0.0033770390758048182
